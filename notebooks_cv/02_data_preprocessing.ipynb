# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/mock-data.csv')
df.head()
# Out:
#          Post_ID                                        Raw_Caption  \
# 0  NYC-MOCK-0001  LOOK | The Philippines co-hosts the National Y...
# 1  NYC-MOCK-0002  READ | NYC leads Digital Literacy for student ...
# 2  NYC-MOCK-0003  #AreaNews | SK Leaders in Quezon City complete...
# 3  NYC-MOCK-0004  READ | NYC leads Mental Health Support for LGB...
# 4  NYC-MOCK-0005  READ | NYC leads Climate Action for LGBTQIA+ y...
#
#   Final Status
# 0     Accepted
# 1     Accepted
# 2     Accepted
# 3     Accepted
# 4     Accepted

# %%
df_clean = df.copy()

# %%
df_clean.to_csv('../data/data-clean.csv', index=False)

# %% [markdown]
# ### Lowercasing

# %% [markdown]
# ### Normalize Whitespace

# %% [markdown]
# ### URL Removal

# %% [markdown]
# ### HTML Tags

# %% [markdown]
# ### Emoji
