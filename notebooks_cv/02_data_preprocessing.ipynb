# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Lowercasing

# %% [markdown]
# ### Normalize Whitespace

# %% [markdown]
# ### URL Removal

# %% [markdown]
# ### HTML Tags

# %% [markdown]
# ### Emoji
#
# Can skip if using BERT models bc they can handle emojis as they are.
