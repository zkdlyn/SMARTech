# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Lowercasing

# %% [markdown]
# ### Normalize Whitespace

# %% [markdown]
# ### URL Removal

# %% [markdown]
# ### HTML Tags

# %% [markdown]
# ### Emoji
